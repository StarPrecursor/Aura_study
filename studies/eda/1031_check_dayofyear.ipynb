# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_feather("/home/yangzhe/model/fr_pred/1030_fut_n_trade/input.feather")

# %%
# Plot funding_rate__future_10 vs time_H__dayofyear
fig, ax = plt.subplots()
ax.scatter(df["time_H__dayofyear"], df["funding_rate__future_10"], s=0.1, alpha=0.1)
ax.set_title("funding_rate__future_10 vs time_H__dayofyear")
ax.set_xlabel("time_H__dayofyear")
ax.set_ylabel("funding_rate__future_10")
fig.show()
